# %% [markdown]
# # DATA CLEANING

# %%
import pandas as pd

# %%
df = pd.concat([
    pd.read_csv(r"C:\Users\VINOTH\Downloads\archive (4)\covid_vaccine_statewise.csv", encoding='latin1'),
    pd.read_csv(r"C:\Users\VINOTH\Downloads\archive (4)\covid_19_india.csv", encoding='latin1'),
    pd.read_csv(r"C:\Users\VINOTH\Downloads\archive (4)\StatewiseTestingDetails.csv", encoding='latin1')
])
df
# Out:
#        Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0      16/01/2021        India                   48276.0    3455.0   2957.0
# 1      17/01/2021        India                   58604.0    8532.0   4954.0
# 2      18/01/2021        India                   99449.0   13611.0   6583.0
# 3      19/01/2021        India                  195525.0   17855.0   7951.0
# 4      20/01/2021        India                  251280.0   25472.0  10504.0
# ...           ...          ...                       ...       ...      ...
# 16331         NaN  West Bengal                       NaN       NaN      NaN
# 16332         NaN  West Bengal                       NaN       NaN      NaN
# 16333         NaN  West Bengal                       NaN       NaN      NaN
# 16334         NaN  West Bengal                       NaN       NaN      NaN
# 16335         NaN  West Bengal                       NaN       NaN      NaN
#
# ...

# %%
df .columns
# Out:
# Index(['Updated On', 'State', 'Total Doses Administered', 'Sessions',
#        ' Sites ', 'First Dose Administered', 'Second Dose Administered',
#        'Male (Doses Administered)', 'Female (Doses Administered)',
#        'Transgender (Doses Administered)', ' Covaxin (Doses Administered)',
#        'CoviShield (Doses Administered)', 'Sputnik V (Doses Administered)',
#        'AEFI', '18-44 Years (Doses Administered)',
#        '45-60 Years (Doses Administered)', '60+ Years (Doses Administered)',
#        '18-44 Years(Individuals Vaccinated)',
#        '45-60 Years(Individuals Vaccinated)',
#        '60+ Years(Individuals Vaccinated)', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Individuals Vaccinated', 'Sno', 'Date', 'Time',
#        'State/UnionTerritory', 'ConfirmedIndianNational',
#        'ConfirmedForeignNational', 'Cured', 'Deaths', 'Confirmed',
# ...

# %%
df.size
# Out:
# 1522476

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42291 entries, 0 to 16335
# Data columns (total 36 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                24181 non-null  object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Updated On                             34446
# State                                  18110
# Total Doses Administered               34670
# Sessions                               34670
#  Sites                                 34670
# First Dose Administered                34670
# Second Dose Administered               34670
# Male (Doses Administered)              34830
# Female (Doses Administered)            34830
# Transgender (Doses Administered)       34830
#  Covaxin (Doses Administered)          34670
# CoviShield (Doses Administered)        34670
# Sputnik V (Doses Administered)         39296
# AEFI                                   36853
# 18-44 Years (Doses Administered)       40589
# 45-60 Years (Doses Administered)       40589
# 60+ Years (Doses Administered)         40589
# 18-44 Years(Individuals Vaccinated)    38558
# 45-60 Years(Individuals Vaccinated)    38557
# 60+ Years(Individuals Vaccinated)      38557
# Male(Individuals Vaccinated)           42131
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Updated On                             0
# State                                  0
# Total Doses Administered               0
# Sessions                               0
#  Sites                                 0
# First Dose Administered                0
# Second Dose Administered               0
# Male (Doses Administered)              0
# Female (Doses Administered)            0
# Transgender (Doses Administered)       0
#  Covaxin (Doses Administered)          0
# CoviShield (Doses Administered)        0
# Sputnik V (Doses Administered)         0
# AEFI                                   0
# 18-44 Years (Doses Administered)       0
# 45-60 Years (Doses Administered)       0
# 60+ Years (Doses Administered)         0
# 18-44 Years(Individuals Vaccinated)    0
# 45-60 Years(Individuals Vaccinated)    0
# 60+ Years(Individuals Vaccinated)      0
# Male(Individuals Vaccinated)           0
# Female(Individuals Vaccinated)         0
# Transgender(Individuals Vaccinated)    0
# ...
